# %%
#importing packages & libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %%
#changing configuration of plots
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)
pd.options.mode.chained_assignment = None

# %%
#importing data
df = pd.read_csv(r'C:\Users\cambw\Downloads\movies.csv')

# %%
#see if data loaded correctly
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#checking for missing values
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
#looking at data types for variables
print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#exploring distribution of data
df.boxplot(column=['gross'])
# Out:
# <Axes: >

# %%
#dropping duplicates just in case
df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#exploring top grossing movies
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                                released  score      votes       director  \
# ...

# %%
#not surprised to see Avatar & Avengers up there
#wanna explore relationship between movie gross earnings & budget
#assume they are correlated due to big blockbluster nature of hollywood but might be able to isolate flops too
#double checking my assumption
sns.regplot(x="gross", y="budget", data=df)
# Out:
# <Axes: xlabel='gross', ylabel='budget'>

# %%
#linear coorelation b/w gross earnings & budget as expected 
#are gross earnings & IMDB scores correlated?
sns.regplot(x="score", y="gross", data=df)
# Out:
# <Axes: xlabel='score', ylabel='gross'>

# %%
#not really but somewhat linear correlation
#exploring what else is correlated to what & to what degree through some statistical tests
#Pearson Method
df.corr(method ='pearson')
# Out:
# C:\Users\cambw\AppData\Local\Temp\ipykernel_12672\3066069532.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method ='pearson')
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
#Kendall Method
df.corr(method ='kendall')
# Out:
# C:\Users\cambw\AppData\Local\Temp\ipykernel_12672\3195584264.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method ='kendall')
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067652  0.331465  0.224120  0.200618  0.097184
# score    0.067652  1.000000  0.300115 -0.000566  0.086046  0.283611
# votes    0.331465  0.300115  1.000000  0.353702  0.548899  0.198240
# budget   0.224120 -0.000566  0.353702  1.000000  0.512637  0.235483
# gross    0.200618  0.086046  0.548899  0.512637  1.000000  0.168933
# runtime  0.097184  0.283611  0.198240  0.235483  0.168933  1.000000

# %%
#Spearman Method
df.corr(method ='spearman')
# Out:
# C:\Users\cambw\AppData\Local\Temp\ipykernel_12672\424315616.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method ='spearman')
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.099045  0.469829  0.317336  0.293084  0.142977
# score    0.099045  1.000000  0.428138 -0.001403  0.126116  0.399857
# votes    0.469829  0.428138  1.000000  0.502466  0.742050  0.290159
# budget   0.317336 -0.001403  0.502466  1.000000  0.693670  0.336370
# gross    0.293084  0.126116  0.742050  0.693670  1.000000  0.246243
# runtime  0.142977  0.399857  0.290159  0.336370  0.246243  1.000000

# %%
#interesting to see values change depending on methods used
#lets explore the data not from statistical perspective but from visual perspective
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation matrix for Numeric Features")
plt.xlabel("Movie features")
plt.ylabel("Movie features")
plt.show()
# Out:
# C:\Users\cambw\AppData\Local\Temp\ipykernel_12672\2147647530.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
#gonna add the categorical stuff in the heatmap matrix too
#gonna use random stuff/monte carlo experiment to determine values
#using factorize to assign a random numeric value for each unique categorical value

df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000  0.143938  0.036367  0.965761  0.959015 -0.046733
# rating    0.143938  1.000000 -0.086723  0.156713  0.146606  0.012595
# genre     0.036367 -0.086723  1.000000  0.037184  0.035940 -0.002437
# year      0.965761  0.156713  0.037184  1.000000  0.993190 -0.044981
# released  0.959015  0.146606  0.035940  0.993190  1.000000 -0.045761
# score    -0.046733  0.012595 -0.002437 -0.044981 -0.045761  1.000000
# votes     0.287776  0.099972  0.023285  0.312401  0.299905 -0.009749
# director  0.745905  0.085520  0.047288  0.770497  0.770876 -0.022687
# writer    0.805211  0.103623  0.033688  0.824770  0.819617 -0.034685
# star      0.731565  0.093116  0.038649  0.756400  0.754468 -0.009896
# country   0.142828  0.000494 -0.015795  0.140216  0.148468  0.023097
# budget    0.277488  0.193353  0.073008  0.300621  0.285691 -0.012642
# gross     0.947324  0.158582  0.038616  0.980873  0.976423 -0.047041
# ...

# %%
#okay, above stuff is statistical information
#let's take a look at it visually now like I did before
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation matrix for Movies")
plt.xlabel("Movie features")
plt.ylabel("Movie features")
plt.show()

# %%
#name & company are correlated?
#i guess it makes sense since many companies have many movies with same IP
#director & gross correlated? 
#makes sense, ppl go to theatres to see the masters' work
#further exploration of correlations
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()
corr_pairs = correlation_mat.unstack()
print(corr_pairs)
# Out:
# name     name        1.000000
#          rating      0.143938
#          genre       0.036367
#          year        0.965761
#          released    0.959015
#                        ...
# runtime  country     0.124154
#          budget      0.112097
#          gross       0.042978
#          company     0.005137
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
#sorting b/w pairs of correlations to visually see a bit better
sorted_pairs = corr_pairs.sort_values(kind="quicksort")
print(sorted_pairs)
# Out:
# budget   company   -0.092249
# company  budget    -0.092249
# genre    rating    -0.086723
# rating   genre     -0.086723
# budget   country   -0.082082
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %%
#now that I have things organized, wanna see just the pairs that have a strong to moderate correlation
#kinda discretionary, but I will choose .5 as base value
strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]
print(strong_pairs)
# Out:
# star      company    0.527116
# company   star       0.527116
#           writer     0.546151
# writer    company    0.546151
# director  company    0.552258
#                        ...
# year      year       1.000000
# genre     genre      1.000000
# rating    rating     1.000000
# company   company    1.000000
# runtime   runtime    1.000000
# Length: 71, dtype: float64

# %%
#makes sense
#companies will recast same star for IP franchises
#writers will typically be hired within same company for IP congruency across films
#directors hired by same company for similar reasons
#wanna transition out of correlation analysis now
#wanna focus on top companies all time by gross revneue
#suspect to see giants like Warner Bros. & Disney at the top, but you never know
CompanyGrossSum = df.groupby('company')[["gross"]].sum()
CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]
CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 
CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 56491421806
# Universal Pictures           52514188890
# Columbia Pictures            43008941346
# Paramount Pictures           40493607415
# Twentieth Century Fox        40257053857
# Walt Disney Pictures         36327887792
# New Line Cinema              19883797684
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Touchstone Pictures          11795832638
# Dreamworks Pictures          11635441081
# Metro-Goldwyn-Mayer (MGM)     9230230105
# Summit Entertainment          8373718838
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7443502667
# Name: gross, dtype: int64

# %%
#as expected; however, surprised to see New Line Cinema, Touchstone Pictures?
#never heard of them
#gonna do some research to cross-check
#ok, so New Line has Lord of the Rings, so that makes sense
#touchstone has some good properties too
#never heard of touchstone's highest grossing film armeggedon, but have watched other popular stuff like Knighmare B4 Christmas
#gonna take a look at top companies by gross by year
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()
CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]
CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 
CompanyGrossSumSorted
# Out:
# company                year
# Walt Disney Pictures   2019    5773131804
# Marvel Studios         2018    4018631866
# Universal Pictures     2015    3834354888
# Twentieth Century Fox  2009    3793491246
# Walt Disney Pictures   2017    3789382071
# Paramount Pictures     2011    3565705182
# Warner Bros.           2010    3300479986
#                        2011    3223799224
# Walt Disney Pictures   2010    3104474158
# Paramount Pictures     2014    3071298586
# Columbia Pictures      2006    2934631933
#                        2019    2932757449
# Marvel Studios         2019    2797501328
# Warner Bros.           2018    2774168962
# Columbia Pictures      2011    2738363306
# Name: gross, dtype: int64

# %%
#damn, as expected, Disney crushed it with recent Star Wars stuff
#same with Marvel franchises 
#im curious about Universal Pictures tho in 2015
#going to cross-check
#yeah, that was the year when Jurrasic Park remake came out, which was massive
#i wanna revisit gross vs. budget relationship
plt.scatter(x=df['budget'], y=df['gross'], alpha=0.5)
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
#i wish i could see that strange outlier to the upper-right
#current competency in python => cannot figure out correct code 
#oh, well gonna move on
#this was mostly exploratory exercise to test out competency
#new to python environment
